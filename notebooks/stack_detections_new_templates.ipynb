# %%
# Get ERT times
import pandas as pd
ert_surveys_file = "survey_times_ERT.csv"
dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %H:%M:%S')
ert_surveys = pd.read_csv(ert_surveys_file, parse_dates=["time_local_start"], date_parser=dateparse)
ert_surveys["time_local_start"] = ert_surveys["time_local_start"].dt.tz_localize("America/Edmonton", ambiguous="infer")
ert_surveys["time_utc_start"] = ert_surveys["time_local_start"].dt.tz_convert(None)
ert_surveys["time_utc_end"] = ert_surveys["time_utc_start"] + pd.Timedelta(30, unit="m")
ert_surveys["time_utc_end"] = pd.to_datetime(ert_surveys["time_utc_end"])
ert_surveys["time_utc_start"] = pd.to_datetime(ert_surveys["time_utc_start"])
# Out:
# /home/genevieve.savard/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# FUNCTIONS

def plot_stack_singlechannels(streams, stack):
    
    ids = [tr.get_id() for tr in streams[0]]
    n = len(ids)
    ncols = 3
    nrows = math.ceil(n/ncols)
    print("n = %d, nrows = %d, ncols = %d" % (n, nrows, ncols))
    
    fig, axs = plt.subplots(nrows, ncols, sharex=True, figsize=(15, 5*nrows))    
    for tr_id, ax in zip(ids, axs.flatten()):
        
        # Plot each event in background
        for st in streams:
            tr = st.select(id=tr_id)
            if not len(tr):
                continue
            else:
                tr = tr[0]             
            t = tr.times("utcdatetime") - tr.stats.starttime
            ax.plot(t, tr.data/tr.max(), color="gray", marker=None, linestyle="-")        
        # Plot stack
        tr = stack.select(id=tr_id)[0]            
        ax.plot(t, tr.data/tr.max(), color="red", marker=None, linestyle="-")
        ax.set_title("%s" % (tr_id))
    plt.show()
    plt.close()

def get_full_template(template):
    st = template.st
    tmin = min([tr.stats.starttime for tr in st])
    wf_len_s = int(8.0/ndt)*ndt
    prepick = 4.0
    pattern = os.path.join(WF_DIR_ROOT_500Hz, tmin.strftime("%Y%m%d"), "*DP*")
    detst = read(pattern, starttime=tmin - prepick, endtime=tmin - prepick + wf_len_s)
    pattern_hawk = os.path.join(WF_DIR_ROOT_HAWK, "*", "*", "*DP*.D.%s*" % tmin.strftime("%Y%m%d"))
    if glob(pattern_hawk):
        detst += read(pattern_hawk, starttime=tmin - prepick, endtime=tmin - prepick + wf_len_s)
    detst.detrend("demean")
    return detst

def get_stack(family):
    
    # Get waveforms
    streams = []
    wf_len_s = int(6.0/ndt)*ndt
    prepick = 2.0
    wf_len = int(wf_len_s/ndt) + 1
    for d in family.detections:        
        #print(d.detect_time)
        pattern = os.path.join(WF_DIR_ROOT, "*", "*..DP*%s*2020*" % (d.detect_time.strftime("%Y-%m-%d_%H")))                                      
        detst = read(pattern, starttime=d.detect_time - prepick, endtime=d.detect_time - prepick + wf_len_s)
        detst.resample(SAMPLING_RATE)
        detst.detrend("demean")
        # Check if traces have same length
        lengths = set([len(tr) for tr in detst])
        if len(lengths) > 1:
            print("Traces don't have same lengths. Fixing")
            tmin = min([tr.stats.starttime for tr in detst])
            tmax = tmin + wf_len
            detst.trim(starttime=tmin, endtime=tmax, fill_value=0, pad=True)
            print(detst)
        
        streams.append(detst)

    lengths = [len(st[0].data) for st in streams]    
    igood = np.argwhere([len(st[0].data) == wf_len for st in streams]).flatten()
    streams = [streams[i] for i in igood]    
    stack = linstack(streams)
    #plot_stack_3c(streams, stack)
#     plot_stack_singlechannels(streams, stack)
    return stack


def plot_stack_3c(streams, stack):
    stations = list(set([tr.stats.station for tr in stack]))
    nsta = len(stations)    
    fig, axs = plt.subplots(nsta, 3, sharex=True, figsize=(15, 5*nsta))
    for i, station in enumerate(stations):
        available_chans = [tr.stats.channel for tr in streams[0].select(station=station)]
        for ich, channel in enumerate(available_chans): #["DPN", "DPE", "DPZ"]):            
            ax = axs[i][ich]
            # Plot each event in background
            for st in streams:
                tr = st.select(station=station, channel=channel)[0]                
                t = tr.times("utcdatetime") - tr.stats.starttime
                ax.plot(t, tr.data/tr.max(), color="gray", marker=None, linestyle="-")
            # Plot stack
            tr = stack.select(station=station, channel=channel)[0]            
            ax.plot(t, tr.data/tr.max(), color="red", marker=None, linestyle="-")
            ax.set_ylabel("%s.%s" % (tr.stats.station, tr.stats.channel))
    plt.show()
    plt.close()

# %%
# MAIN

from eqcorrscan.utils.stacking import linstack
from eqcorrscan.core.match_filter import Party, Family
from obspy import read, Catalog
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
import math
from glob import glob
import os
from collections import Counter
import numpy as np

DETECT_DIR = "/home/gilbert_lab/cami_frs/borehole_data/energy_detector/detections_clean"
WF_DIR_ROOT_500Hz = "/home/gilbert_lab/cami_frs/borehole_data/sac_daily_nez_500Hz"
WF_DIR_ROOT_HAWK = "/home/gilbert_lab/cami_frs/hawk_data/sac_data_raw/"
WF_DIR_ROOT = "/home/gilbert_lab/cami_frs/sac_hourly_125Hz/"
SAMPLING_RATE = 125.0
ndt = 1/SAMPLING_RATE

party_dir = "/home/gilbert_lab/cami_frs/borehole_data/energy_detector/initial_templates_daily_old/"
out_dir = "/home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates"

flist = glob(os.path.join(party_dir,"party_day202002*.tgz"))
days = [os.path.split(f)[1].split("_")[1].split(".")[0].split("day")[1] for f in flist]
days.sort()
days = days[14:]
total_count = 0
for daystr in days: 
    print("************ %s ************" % daystr)
    party = Party().read(os.path.join(party_dir,"party_day%s.tgz" % daystr))
    print(party)
    #party.decluster(trig_int=3.0)
    print("finished reading and declustering")
    if not party.families:
        print("no families...")
        continue
    count = 0
    for family in party:
        ndets = 0
        if not family:            
            continue
            
        # Determine good detections
        ndets = 0
        good_detections = []
        good_catalog = Catalog()
        for idet, d in enumerate(family.detections):
            detect_time = d.detect_time._get_datetime()
            is_ert_on = ert_surveys.loc[(ert_surveys['time_utc_start'] <= detect_time) & (ert_surveys['time_utc_end'] >= detect_time)].shape[0] > 0
            if not is_ert_on:
                ndets += 1
                good_detections.append(d)
                good_catalog.append(family.catalog[idet])
        if not good_detections:
            continue            
        new_fam = Family(template=family.template, detections=good_detections)
        
        # If family is good, save template and stack
        num_p_picks = len([p for p in new_fam.template.event.picks if p.phase_hint=="P"])
        if ndets > 2 and len(new_fam.template.st) > 4 and num_p_picks > 0:
            count +=1
            print("Family with %d detections" % ndets)
            full_template_st = get_full_template(new_fam.template)
            fname = os.path.join(out_dir, "%s_full_template.mseed" % new_fam.template.name)
            if os.path.exists(fname):
                os.remove(fname)
            new_fam.template.st.write(fname, format="MSEED") 
            full_template_st.write(fname, format="MSEED") 
            
            # stack
            fname = os.path.join(out_dir, "%s_stack.mseed" % new_fam.template.name)
            if os.path.exists(fname):
                os.remove(fname)
            stack = get_stack(new_fam)            
            stack.write(fname, format="MSEED") 
            
            # Family
            fname = os.path.join(out_dir, "%s_family.tgz" % new_fam.template.name)
            if os.path.exists(fname):
                os.remove(fname)
            new_fam.write(fname) 
            
    print("Number of good families: %d / %d" % (count, len(party.families)))
    total_count += count
    
print("total count = %d" % total_count)
# Out:
# ************ 20200228 ************
# Party of 19 Families.
# finished reading and declustering
# Number of good families: 0 / 19
# ************ 20200229 ************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-141-15c3b9b86cd2> in <module>
#      30 for daystr in days:
#      31     print("************ %s ************" % daystr)
# ---> 32     party = Party().read(os.path.join(party_dir,"party_day%s.tgz" % daystr))
#      33     print(party)
#      34     #party.decluster(trig_int=3.0)
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/eqcorrscan/core/match_filter/party.py in read(self, filename, read_detection_catalog, estimate_origin)
#     751             # Read in families here!
#     752             party_dir = glob.glob(temp_dir + os.sep + '*')[0]
# --> 753             tribe._read_from_folder(dirname=party_dir)
#     754             det_cat_file = glob.glob(os.path.join(party_dir, "catalog.*"))
#     755             if len(det_cat_file) != 0 and read_detection_catalog:
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/eqcorrscan/core/match_filter/tribe.py in _read_from_folder(self, dirname)
#     369         tribe_cat_file = glob.glob(os.path.join(dirname, "tribe_cat.*"))
#     370         if len(tribe_cat_file) != 0:
# --> 371             tribe_cat = read_events(tribe_cat_file[0])
#     372         else:
#     373             tribe_cat = Catalog()
#
# <decorator-gen-171> in read_events(pathname_or_url, format, **kwargs)
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/core/util/decorator.py in _map_example_filename(func, *args, **kwargs)
#     298                         except IOError:
#     299                             pass
# --> 300         return func(*args, **kwargs)
#     301     return _map_example_filename
#     302
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/core/event/catalog.py in read_events(pathname_or_url, format, **kwargs)
#     810         return _create_example_catalog()
#     811     else:
# --> 812         return _generic_reader(pathname_or_url, _read, format=format, **kwargs)
#     813
#     814
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/core/util/base.py in _generic_reader(pathname_or_url, callback_func, **kwargs)
#     699                 raise IOError(2, "No such file or directory", pathname)
#     700
# --> 701         generic = callback_func(pathnames[0], **kwargs)
#     702         if len(pathnames) > 1:
#     703             for filename in pathnames[1:]:
#
# <decorator-gen-172> in _read(filename, format, **kwargs)
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/core/util/decorator.py in uncompress_file(func, filename, *args, **kwargs)
#     208     else:
#     209         # no compressions
# --> 210         result = func(filename, *args, **kwargs)
#     211     return result
#     212
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/core/event/catalog.py in _read(filename, format, **kwargs)
#     819     """
#     820     catalog, format = _read_from_plugin('event', filename, format=format,
# --> 821                                         **kwargs)
#     822     for event in catalog:
#     823         event._format = format
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/core/util/base.py in _read_from_plugin(plugin_type, filename, format, **kwargs)
#     467         raise TypeError(msg % (format_ep.name, ', '.join(eps)))
#     468     # read
# --> 469     list_obj = read_format(filename, **kwargs)
#     470     return list_obj, format_ep.name
#     471
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/io/quakeml/core.py in _read_quakeml(filename)
#    1824     2006-09-10T04:26:33.610000Z |  +9.614, +121.961 | 9.8 MS
#    1825     """
# -> 1826     return Unpickler().load(filename)
#    1827
#    1828
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/io/quakeml/core.py in load(self, file)
#     151         """
#     152         self.xml_doc = _xml_doc_from_anything(file)
# --> 153         return self._deserialize()
#     154
#     155     def loads(self, string):
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/io/quakeml/core.py in _deserialize(self)
#     997             self._extra(event_el, event)
#     998             # bind event scoped resource IDs to this event
# --> 999             event.scope_resource_ids()
#    1000             catalog.append(event)
#    1001
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/core/event/event.py in scope_resource_ids(self)
#     332             if attr == 'resource_id':
#     333                 resource_id.set_referred_object(parent, parent=self,
# --> 334                                                 warn=False)
#     335             else:
#     336                 resource_id._parent_key = self
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/core/event/resourceid.py in set_referred_object(self, referred_object, warn, parent)
#     455             if self._parent_key not in id_tree:
#     456                 id_tree[self._parent_key] = WeakKeyDictionary()
# --> 457             id_tree[self._parent_key][self._resource_key] = self._object_key
#     458         # Set the new id in id map and append referred_object to id_order.
#     459         ResourceIdentifier._id_object_map[self._object_key] = referred_object
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/weakref.py in __setitem__(self, key, value)
#     405
#     406     def __setitem__(self, key, value):
# --> 407         self.data[ref(key, self._remove)] = value
#     408
#     409     def copy(self):
#
# KeyboardInterrupt:

# %%
# Just get full template from tribe files

from eqcorrscan.core.match_filter import Tribe

flist = glob(os.path.join(party_dir,"tribe_day*.tgz"))
days = [os.path.split(f)[1].split("_")[1].split(".")[0].split("day")[1] for f in flist]
days.sort()
for daystr in days: 
    print("************ %s ************" % daystr)
    tribe = Tribe().read(os.path.join(party_dir,"tribe_day%s.tgz" % daystr))
    print(tribe)
    if not tribe.templates:
        print("no templates...")
        continue
    
    for template in tribe:        
        if not template:            
            continue                    
        fname = os.path.join(out_dir, "%s_full_template.mseed" % template.name)
        if os.path.exists(fname):
            continue
        num_p_picks = len([p for p in template.event.picks if p.phase_hint=="P"])
        has_magn = len(template.event.magnitudes) > 0
        if len(template.st) > 5 and (num_p_picks > 0 or has_magn):
            print(template.name)
            full_template_st = get_full_template(template)
            full_template_st.write(fname, format="MSEED") 
            print("Saving %s" % fname)
            fname = fname.replace("full_template.mseed", "template.tgz")
            template.write(fname)
            print("Saving %s" % fname)
# Out:
# ************ 20200108 ************
# Tribe of 160 templates
# ************ 20200109 ************
# Tribe of 309 templates
# ************ 20200110 ************
# Tribe of 56 templates
# ************ 20200122 ************
# Tribe of 117 templates
# 2020_01_22t21_26_46
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_22t21_26_46_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_22t21_26_46_template.tgz
# 2020_01_22t21_35_42
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_22t21_35_42_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_22t21_35_42_template.tgz
# 2020_01_22t21_27_31
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_22t21_27_31_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_22t21_27_31_template.tgz
# 2020_01_22t21_34_19
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_22t21_34_19_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_22t21_34_19_template.tgz
# 2020_01_22t21_11_19
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_22t21_11_19_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_22t21_11_19_template.tgz
# 2020_01_22t21_35_11
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_22t21_35_11_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_22t21_35_11_template.tgz
# 2020_01_22t21_34_00
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_22t21_34_00_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_22t21_34_00_template.tgz
# 2020_01_22t21_11_24
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_22t21_11_24_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_22t21_11_24_template.tgz
# 2020_01_22t22_03_19
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_22t22_03_19_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_22t22_03_19_template.tgz
# 2020_01_22t22_19_19
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_22t22_19_19_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_22t22_19_19_template.tgz
# ************ 20200124 ************
# Tribe of 431 templates
# 2020_01_24t00_13_49
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t00_13_49_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t00_13_49_template.tgz
# 2020_01_24t00_13_44
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t00_13_44_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t00_13_44_template.tgz
# 2020_01_24t00_13_40
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t00_13_40_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t00_13_40_template.tgz
# 2020_01_24t00_12_24
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t00_12_24_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t00_12_24_template.tgz
# 2020_01_24t02_17_05
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t02_17_05_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t02_17_05_template.tgz
# 2020_01_24t02_37_25
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t02_37_25_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t02_37_25_template.tgz
# 2020_01_24t03_32_54
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t03_32_54_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t03_32_54_template.tgz
# 2020_01_24t03_37_54
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t03_37_54_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t03_37_54_template.tgz
# 2020_01_24t04_13_54
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t04_13_54_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t04_13_54_template.tgz
# 2020_01_24t04_38_54
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t04_38_54_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t04_38_54_template.tgz
# 2020_01_24t06_55_54
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t06_55_54_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t06_55_54_template.tgz
# 2020_01_24t07_06_53
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t07_06_53_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t07_06_53_template.tgz
# 2020_01_24t08_17_24
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t08_17_24_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t08_17_24_template.tgz
# 2020_01_24t08_16_54
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t08_16_54_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t08_16_54_template.tgz
# 2020_01_24t08_37_54
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t08_37_54_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t08_37_54_template.tgz
# 2020_01_24t16_08_12
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t16_08_12_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t16_08_12_template.tgz
# 2020_01_24t16_28_50
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t16_28_50_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t16_28_50_template.tgz
# 2020_01_24t16_33_52
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t16_33_52_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t16_33_52_template.tgz
# 2020_01_24t16_28_40
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t16_28_40_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t16_28_40_template.tgz
# 2020_01_24t16_07_51
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t16_07_51_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t16_07_51_template.tgz
# 2020_01_24t16_28_56
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t16_28_56_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t16_28_56_template.tgz
# 2020_01_24t16_08_16
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t16_08_16_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t16_08_16_template.tgz
# 2020_01_24t16_08_08
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t16_08_08_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t16_08_08_template.tgz
# 2020_01_24t16_08_21
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t16_08_21_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_24t16_08_21_template.tgz
# ************ 20200125 ************
# Tribe of 1 templates
# ************ 20200126 ************
# Tribe of 352 templates
# 2020_01_26t07_24_36
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_26t07_24_36_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_26t07_24_36_template.tgz
# 2020_01_26t07_55_28
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_26t07_55_28_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_26t07_55_28_template.tgz
# 2020_01_26t07_55_31
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_26t07_55_31_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_26t07_55_31_template.tgz
# 2020_01_26t07_55_23
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_26t07_55_23_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_26t07_55_23_template.tgz
# 2020_01_26t08_30_35
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_26t08_30_35_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_26t08_30_35_template.tgz
# 2020_01_26t08_47_36
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_26t08_47_36_full_template.mseed
# Saving /home/gilbert_lab/cami_frs/borehole_data/energy_detector/templates/2020_01_26t08_47_36_template.tgz
# 2020_01_26t08_32_04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-148-49ffce9489e9> in <module>
#      24         if len(template.st) > 5 and (num_p_picks > 0 or has_magn):
#      25             print(template.name)
# ---> 26             full_template_st = get_full_template(template)
#      27             full_template_st.write(fname, format="MSEED")
#      28             print("Saving %s" % fname)
#
# <ipython-input-143-cdff90969635> in get_full_template(template)
#      34     prepick = 4.0
#      35     pattern = os.path.join(WF_DIR_ROOT_500Hz, tmin.strftime("%Y%m%d"), "*DP*")
# ---> 36     detst = read(pattern, starttime=tmin - prepick, endtime=tmin - prepick + wf_len_s)
#      37     pattern_hawk = os.path.join(WF_DIR_ROOT_HAWK, "*", "*", "*DP*.D.%s*" % tmin.strftime("%Y%m%d"))
#      38     if glob(pattern_hawk):
#
# <decorator-gen-156> in read(pathname_or_url, format, headonly, starttime, endtime, nearest_sample, dtype, apply_calib, check_compression, **kwargs)
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/core/util/decorator.py in _map_example_filename(func, *args, **kwargs)
#     298                         except IOError:
#     299                             pass
# --> 300         return func(*args, **kwargs)
#     301     return _map_example_filename
#     302
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/core/stream.py in read(pathname_or_url, format, headonly, starttime, endtime, nearest_sample, dtype, apply_calib, check_compression, **kwargs)
#     210         st = _create_example_stream(headonly=headonly)
#     211     else:
# --> 212         st = _generic_reader(pathname_or_url, _read, **kwargs)
#     213
#     214     if len(st) == 0:
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/core/util/base.py in _generic_reader(pathname_or_url, callback_func, **kwargs)
#     702         if len(pathnames) > 1:
#     703             for filename in pathnames[1:]:
# --> 704                 generic.extend(callback_func(filename, **kwargs))
#     705         return generic
#     706
#
# <decorator-gen-157> in _read(filename, format, headonly, **kwargs)
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/core/util/decorator.py in uncompress_file(func, filename, *args, **kwargs)
#     208     else:
#     209         # no compressions
# --> 210         result = func(filename, *args, **kwargs)
#     211     return result
#     212
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/core/stream.py in _read(filename, format, headonly, **kwargs)
#     255     """
#     256     stream, format = _read_from_plugin('waveform', filename, format=format,
# --> 257                                        headonly=headonly, **kwargs)
#     258     # set _format identifier for each element
#     259     for trace in stream:
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/core/util/base.py in _read_from_plugin(plugin_type, filename, format, **kwargs)
#     467         raise TypeError(msg % (format_ep.name, ', '.join(eps)))
#     468     # read
# --> 469     list_obj = read_format(filename, **kwargs)
#     470     return list_obj, format_ep.name
#     471
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/io/sac/core.py in _read_sac(filename, headonly, debug_headers, fsize, **kwargs)
#     349             return _internal_read_sac(buf=fh, headonly=headonly,
#     350                                       debug_headers=debug_headers, fsize=fsize,
# --> 351                                       **kwargs)
#     352     else:
#     353         raise ValueError("Cannot open '%s'." % filename)
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/io/sac/core.py in _internal_read_sac(buf, headonly, debug_headers, fsize, byteorder, **kwargs)
#     393     sac = SACTrace.read(buf, headonly=headonly, ascii=False,
#     394                         byteorder=byteorder, checksize=fsize,
# --> 395                         encoding=encoding_str)
#     396     # assign all header entries to a new dictionary compatible with an ObsPy
#     397     tr = sac.to_obspy_trace(debug_headers=debug_headers, encoding=encoding_str)
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/io/sac/sactrace.py in read(cls, source, headonly, ascii, byteorder, checksize, debug_strings, encoding)
#    1088             hf, hi, hs, data = _io.read_sac(source, headonly=headonly,
#    1089                                             byteorder=byteorder,
# -> 1090                                             checksize=checksize)
#    1091         if not debug_strings:
#    1092             for i, val in enumerate(hs):
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/io/sac/arrayio.py in read_sac(source, headonly, byteorder, checksize)
#     184     else:
#     185         data = from_buffer(f.read(int(npts) * 4),
# --> 186                            dtype=native_str(endian_str + 'f4'))
#     187
#     188         if len(data) != npts:
#
# ~/anaconda3/envs/eqcorrscan/lib/python3.6/site-packages/obspy/core/compatibility.py in from_buffer(data, dtype)
#      86         except Exception:
#      87             pass
# ---> 88         return np.array(memoryview(data)).view(dtype).copy()  # NOQA
#      89
#      90
#
# KeyboardInterrupt:

# %%
days.index(daystr)
# Out:
# 6

# %%
# Out:
# 127
